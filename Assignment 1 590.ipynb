# %% [markdown]
# ### Assignment 1 ANLY590

# %% [markdown]
# ### Zhen Zhong

# %% [markdown]
#  ### Feedforward: Building a ReLu 2 Layer neural network

# %% [markdown]
#  #### 1.Plot (draw) a network with:(1) inputs (2) hidden layers (where the first layer contains 3 hidden units and thesecond contains 2 hidden units) and a (3) 3-class output (use asoftmaxfunction)

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
img = imread('network.png')
plt.figure(figsize = (10, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 2.  Write out the mathematical equation for this network

# %% [markdown]
# $h_{1i}=max(0,x_1w_{1i}^{(1)}+x_2w_{2i}^{(1)}+b_{i}^{(1)})$ for $i=1,2,3$

# %% [markdown]
# $h_{2j}=max(0,h_{1}^{(1)}w_{1j}^{(2)}+h_{2}^{(1)}w_{2j}^{(2)}+h_{3}^{(1)}w_{3j}^{(2)}+b_{i}^{(2)})$ for $j=1,2$

# %% [markdown]
# $y_k=softmax(h_{1}^{(2)}v_{1k}+h_{2}^{(2)}v_{2k}+c_k)=\frac{exp(h_{1}^{(2)}v_{1k}+h_{2}^{(2)}v_{2k}+c_k)}{\sum_{i=1}^{3} exp(h_{1}^{(2)}v_{1i}+h_{2}^{(2)}v_{2i}+c_k)}$ for $k=1,2,3$

# %% [markdown]
# #### 3. Write out the function in python, call it ff_nn_2_ReLu(...)

# %%
import numpy as np
#Import all the parameter we need 
def ff_nn_2_ReLu(x, parameters):
    w1, b1, w2, b2, v, c = parameters
    relu = np.vectorize(lambda z: np.fmax(0,z))
    softmax = lambda z: np.exp(z)/np.sum(np.exp(z), axis = 1, 
                                         keepdims=True)
    a1 = x.dot(w1) + b1
    h1 = relu(a1)
    a2 = h1.dot(w2) + b2
    h2 = relu(a2)
    a3 = h2.dot(v) + c
    out = np.round(softmax(a3), 2)
    return h1, h2, out

# %% [markdown]
# #### 4. Suppose you have the following set of weight matrices,what are the class probabilities associated with the forward pass of eachsample?

# %%
X = np.array(([1, 0, 0], [-1, -1, 1]))
W1 = np.array(([1, 0], [-1, 0], [0, 0.5]))
W2 = np.array(([1, 0, 0], [-1, -1, 0]))
V = np.array(([1, 1], [0, 0], [-1, -1]))
b1 = np.array([0, 0, 1])
b2 = np.array([1, -1])
c = np.array([1, 0, 0])
parameters = [W1.T, b1, W2.T, b2, V.T, c]
ff_nn_2_ReLu(X.T, parameters)[-1]
# Out:
# array([[0.95, 0.05, 0.01],
#        [0.84, 0.11, 0.04],
#        [0.84, 0.11, 0.04]])

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# #### 1.What are the partial derivatives of f with respect to x and to y?

# %% [markdown]
# $\frac{\partial f}{\partial x}=2(x-1)+200*2x*(x^2-y)=400x^3-400xy+2x-2$

# %% [markdown]
# $\frac{\partial f}{\partial y}=200*(y-x^2)=-200x^2+200y$

# %% [markdown]
# #### 2. Create a visualization of the contours of the Rosenbrock function.

# %%
delta = 0.001
x = np.arange(-5.0, 5.0, delta)
y = np.arange(-5.0, 5.0, delta)
X, Y = np.meshgrid(x, y)
f = (1-X)**2 + 100*(Y-X**2)**2
plt.contour(X, Y, f,20)

# %% [markdown]
# #### 3. Write a Gradient Descent algorithm for finding the minimum of the func-tion.  Visualize your results with a few different learning rates.

# %%
# --- Defining gradient ----
def grad_f(vector):
    x, y = vector
    df_dx = 400*x**3-400*x*y+2*x-2 
    df_dy = -200*x**2+200*y
    return np.array([df_dx, df_dy])

# --- Grad Descent ----
# Set the iterations=50, learning rate=10
def grad_descent(starting_point=None, iterations=50, learning_rate=10):
    if starting_point:
        point = starting_point
    else:
        point = np.random.uniform(-1,1,size=2)
    trajectory = [point]
    
    for i in range(iterations):
        grad = grad_f(point)
        point = point - learning_rate * grad
        trajectory.append(point)
    return np.array(trajectory)

# %%
# --- Visualize Trajectory ---

##learning rate=0.05
np.random.seed(10)
traj = grad_descent(iterations=50, learning_rate=0.05) 
plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
# --- Visualize Trajectory ---

##learning rate =0.01
np.random.seed(10)
traj = grad_descent(iterations=50, learning_rate=0.01) 

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
# --- Visualize Trajectory ---

## learning rate = 0.005
np.random.seed(10)
traj = grad_descent(iterations=50, learning_rate=0.005)  

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
# --- Visualize Trajectory ---

##learning rate=0.001
np.random.seed(10)
traj = grad_descent(iterations=50, learning_rate=0.001)  

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
# --- Visualize Trajectory ---

##learning rate=0.0005
np.random.seed(10)
traj = grad_descent(iterations=50, learning_rate=0.0005)  

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %% [markdown]
# #### 4. Write a Gradient Descent With Momentum algorithm for finding the mini-mum. Visualize your results with a few different settings of the algorithm’shyperparameters.

# %%
# --- Gradient with momentum ---
def grad_descent_with_momentum(starting_point=None, iterations=50, alpha=.8, epsilon=9):
    if starting_point:
        point = starting_point
    else:
        point = np.random.uniform(-1,1,size=2)
    trajectory = [point]
    v = np.zeros(point.size)
    
    for i in range(iterations):
        grad = grad_f(point)
        v = alpha*v + epsilon*grad
        point = point - v
        trajectory.append(point)
    return np.array(trajectory)

# %% [markdown]
# First, we set the alpha fixed and see the trend when epsilon changes.

# %%
# --- Visualizing trajectory --

## episilon = 0.01, alpha = 0.8
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.01, alpha=.8)

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
# --- Visualizing trajectory --

## episilon = 0.005, alpha = 0.8

np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.005, alpha=.8)

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in double_scalars
#   """
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """

# %%
# --- Visualizing trajectory --

## episilon = 0.001, alpha = 0.8
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.001, alpha=.8)

plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
# --- Visualizing trajectory --
## episilon = 0.0005, alpha = 0.8
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.0005, alpha=.8)
plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %% [markdown]
# Then we set epsilon fixed and change the alpha.

# %%
# --- Visualizing trajectory --
## episilon = 0.001, alpha = 0.6
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.001, alpha=.6)
plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
# --- Visualizing trajectory --
## episilon = 0.001, alpha = 0.1
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.001, alpha=.1)
plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
# --- Visualizing trajectory --
## episilon = 0.001, alpha = 0.1
np.random.seed(10)
traj = grad_descent_with_momentum(iterations=50, epsilon=0.001, alpha=0.05)
plt.contour(X, Y, f)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %% [markdown]
# It seems the the changes of epsilon causes the larger change in function that the change of alpha.

# %% [markdown]
# ### Backprop

# %% [markdown]
# #### 1.For the same network as in Number 1, derive expressions of the gradientof the Loss function with respect to each of the model parameters.

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial c_s}=(\mathbb 1\rvert_{s_n=true class}-\hat y_s)$, for $s = 1, 2, 3$

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial V_{ks}} = (\mathbb 1\rvert_{s_n=true class}-\hat y_s)h^{(2)}_k$, for $k = 1, 2$

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial b^{(2)}_k} = \sum_s(\mathbb 1\rvert_{s_n=true class}-\hat y_s)V_{ks}\mathbb 1_{a_k>0}$

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial W^{(2)}_{jk}} = \sum_s(\mathbb 1\rvert_{s_n=true class}-\hat y_s)V_{ks}\mathbb 1_{a_k>0}h_{j}^{(1)}$, for $j=1,2,3$

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial b^{(1)}_j} = \sum_s\sum_k(\mathbb 1\rvert_{s_n=true class}-\hat y_s)V_{ks}W^{(2)}_{jk}\mathbb 1_{a_k>0}\mathbb 1_{a_j>0} $

# %% [markdown]
# $\frac{\partial L(y,\hat y)}{\partial W^{(1)}_{ij}} = \sum_s\sum_k(\mathbb 1\rvert_{s_n=true class}-\hat y_s)V_{ks}W^{(2)}_{jk}\mathbb 1_{a_k>0}\mathbb 1_{a_j>0} x_{i}$, for $i = 1,2$

# %% [markdown]
# #### 2. Write a functiongradf(...)that takes in a weights vector and returnsthe gradient of the Loss at that location.

# %%
def grad(X,H1,H2,Y,Y_hat,parameters):  
    # Unpacking parameters    
    W1,b1,W2,b2,V,c = parameters

    # Gradients - ReLU
    dV = H2.T.dot(Y_hat - Y)
    dc = (Y_hat - Y).sum(axis=0)
    dW2 = H1.T.dot(((Y_hat - Y).dot(V.T) * (H2 > 0))) 
    db2 = ((Y_hat - Y).dot(V.T) * (H2 > 0)).sum(axis=0)
    dW1 = X.T.dot((((Y_hat - Y).dot(V.T)* (H2 > 0)).dot(W2.T)* (H1 > 0)))
    db1 = (((Y_hat - Y).dot(V.T)* (H2 > 0)).dot(W2.T)* (H1 > 0)).sum(axis=0)    
    
    #return {'dV':dV,'db2':db2,'dW':dW,'db1':db1}
    return dW1,db1,dW2,db2,dV,dc

# %% [markdown]
# #### 3.Generate a synthetic dataset of 3 equally sampled bivariate Gaussian dis-tributions with parameters that you’ll use for fitting your network.  Plot your sample dataset, coloringdata points by their respective class.

# %%
import pandas as pd 

#Set the a sufficient large sample size to ensure acccuracy 
def get_synthe(n = 999, plot=False):
    np.random.seed(123)
    
    # Parameters of a normal distribuion
    mean1 = [0, 2] ; mean2 = [2, -2] ; mean3 = [-2, -2]
    mean = [mean1, mean2, mean3] ; cov = [[1, 0], [0, 1]]  
    
    # Setting up the class probabilities
    
    ##Equal probability
    p1 = p2 = p3 = 1/3.0
    n_class = (n * np.array([p1,p2, p3])).astype(int)
  
    # Generate sample data
    for i in range(3):
        x1,x2 = np.random.multivariate_normal(mean[i], cov, n_class[i]).T
        if (i==0):
            xs = np.array([x1,x2])
            cl = np.array([n_class[i]*[i]])
        else: 
            xs_new = np.array([x1,x2])
            cl_new = np.array([n_class[i]*[i]])
            xs = np.concatenate((xs, xs_new), axis = 1)
            cl = np.concatenate((cl, cl_new), axis = 1)
    # Set up the plot position
    if plot:
        plt.scatter(xs[:1,:],xs[1:,:], c = cl)

    # One hot encoding classes
    y = pd.Series(cl[0].tolist())
    y = pd.get_dummies(y).as_matrix() 

     # Normalizing    
    mu = xs.mean(axis = 1)
    std = xs.std(axis = 1)
    xs = (xs.T - mu) / std
    
    return xs, y, cl
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Generate data for network    #
#################################
X, Y, cl = get_synthe(plot = True)
# Out:
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %% [markdown]
# #### 4.Fit your network using Gradient Descent.  Keep track of the total Loss ateach iteration and plot the result.

# %%
#Update parameter by update the momentum and regularization
def parameter_update(parameters,  grads, 
                     momentum_params = [0,0,0,0,0,0], 
                     lr = 1, reg = 0, alpha = 0):
    # Unpacking parameters            
    W1,b1,W2,b2,V,c = parameters
    dW1,db1,dW2,db2,dV,dc = grads
    vW1,vb1,vW2,vb2,vV,vc = momentum_params
    
    # Momentum update
    vW1  = alpha * vW1 -  lr * (dW1 + reg*W1)
    vb1 = alpha * vb1 - lr * (db1 + reg*b1)
    vW2  = alpha * vW2 -  lr * (dW2 + reg*W2)
    vb2 = alpha * vb2 - lr * (db2 + reg*b2)
    vV  = alpha * vV -  lr * (dV + reg*V)
    vc = alpha * vc - lr * (dc + reg*c)
    momentum_params = [vW1,vb1,vW2,vb2,vV,vc] 
    
    # Parameter updates
    W1  = W1  + vW1
    b1 = b1 + vb1
    W2  = W2  + vW2
    b2 = b2 + vb2    
    V  = V  + vV
    c = c + vc
    parameters =[W1,b1,W2,b2,V,c]

             
    return parameters, momentum_params

# %%
#Utility Function
def predict(Y_hat):
    return np.argmax(Y_hat, axis=1)


def error_rate(Y_hat, cl):
    prediction = predict(Y_hat)
    return np.mean(prediction != cl)


def cost(Y_hat, Y):
    tot = Y * np.log(Y_hat)
    return -tot.sum()

# %%
def execution(X, Y, cl,
              iterations = 1000,
              regularization_include = False,
              momentum_include = False):    

    ###################################
    #   Initial values for network    #
    ###################################
    # Intialize weights
    np.random.seed(123)
    W1 = np.random.randn(6).reshape(3,2)
    b1 = np.array([0,0,0])
    W2 = np.random.randn(6).reshape(2,3)
    b2 = np.array([0,0])
    V = np.random.randn(6).reshape(3,2)
    c = np.array([0,0,0])
    parameters = [W1.T, b1, W2.T, b2, V.T, c]
    
    # Hyperparameters 
    lr = 0.0001 # learning rate
    reg = 0.01 * regularization_include
    
    # Momentum parameters
    alpha = 0.9 * momentum_include
    vV = 0
    vc = 0
    vW2 = 0
    vb2 = 0
    vW1 = 0
    vb1 = 0
    momentum_params = [vW1,vb1,vW2,vb2,vV,vc]    
    
    # Place holder for losses
    losses = []
    errors = []    
   
    ###################
    #   Run the model #
    ###################
    for i in range(0,iterations):
        #print(i)
        # -- Forward propoagation --
        H1,H2,Y_hat = ff_nn_2_ReLu(X,parameters)
        
        # -- Backward propagation --
        # Gradient calculation
        grads_in = grad(X,H1,H2,Y,Y_hat,parameters)
        # Parameter update
        new_params, new_mom_param = parameter_update(parameters, grads_in, 
                             momentum_params, alpha = alpha, 
                             lr = lr, reg = reg)
        # -- Updating values --
        H1,H2,Y_hat = ff_nn_2_ReLu(X,new_params)
        parameters = new_params
        momentum_params = new_mom_param
        
        # Prediction and Error rate            
        errs_i = error_rate(Y_hat, cl) ; errors.append(errs_i)
        loss_i = cost(Y_hat, Y); losses.append(loss_i)
        if ((i % 25) == 0):    
            print(
            '''
            ---- Iteration {i} ----
            Error rate : {er}
            Loss: {loss}
            '''.format(i= i, er = errs_i, loss = loss_i))
    plt.plot(losses)
    return {"errors":errs_i, "loss_i":loss_i, "parameters":parameters}

# %%
result = execution(X,Y,cl, iterations = 100,
          regularization_include = False,
          momentum_include = False)
# Out:
#             ---- Iteration 0 ----
#             Error rate : 0.7767767767767768
#             Loss: 1110.777768881103
#
#
#             ---- Iteration 25 ----
#             Error rate : 0.6626626626626627
#             Loss: 1102.489074472399
#
#
#             ---- Iteration 50 ----
#             Error rate : 0.6556556556556556
#             Loss: 1082.0979124723708
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\Zhen\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in multiply
#             ---- Iteration 75 ----
#             Error rate : 0.34234234234234234
#             Loss: nan

# %% [markdown]
# #### In order to prevent np.log(Y_hat) be invalid, we add a small number which 0.000001 to let it non-zero

# %%
def cost(Y_hat, Y):
    tot = Y * np.log(Y_hat+0.000001)
    return -tot.sum()
result = execution(X,Y,cl, iterations = 500,
          regularization_include = False,
          momentum_include = False)
# Out:
#             ---- Iteration 0 ----
#             Error rate : 0.7767767767767768
#             Loss: 1110.774689701927
#
#
#             ---- Iteration 25 ----
#             Error rate : 0.6626626626626627
#             Loss: 1102.486044310498
#
#
#             ---- Iteration 50 ----
#             Error rate : 0.6556556556556556
#             Loss: 1082.094915152894
#
#
#             ---- Iteration 75 ----
#             Error rate : 0.34234234234234234
#             Loss: 900.7304838172676
#
#
#             ---- Iteration 100 ----
#             Error rate : 0.32732732732732733
#             Loss: 684.6685417300437
#
#
#             ---- Iteration 125 ----
#             Error rate : 0.3033033033033033
#             Loss: 617.9601067009881
#
#
#             ---- Iteration 150 ----
#             Error rate : 0.2822822822822823
#             Loss: 589.9973964793488
#
#
#             ---- Iteration 175 ----
#             Error rate : 0.26626626626626626
# ...

# %% [markdown]
# #### 5. Repeat the exercise above using Momentum.  Comment on whether youralgorithm seems to converge more efficiently.

# %%
result = execution(X,Y,cl, iterations = 500,
          regularization_include = False,
          momentum_include = True)
# Out:
#             ---- Iteration 0 ----
#             Error rate : 0.7767767767767768
#             Loss: 1110.774689701927
#
#
#             ---- Iteration 25 ----
#             Error rate : 0.3483483483483483
#             Loss: 802.8053479917066
#
#
#             ---- Iteration 50 ----
#             Error rate : 0.34534534534534533
#             Loss: 523.1214418732927
#
#
#             ---- Iteration 75 ----
#             Error rate : 0.32232232232232233
#             Loss: 510.36987554336145
#
#
#             ---- Iteration 100 ----
#             Error rate : 0.32232232232232233
#             Loss: 507.9968859350571
#
#
#             ---- Iteration 125 ----
#             Error rate : 0.3133133133133133
#             Loss: 501.59344789942304
#
#
#             ---- Iteration 150 ----
#             Error rate : 0.25625625625625625
#             Loss: 496.0944244396017
#
#
#             ---- Iteration 175 ----
#             Error rate : 0.11211211211211211
# ...

# %% [markdown]
# We can clearly see that by adding momentum, it converges more quickly.
